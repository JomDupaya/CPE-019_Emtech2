# %% [markdown]
# | <h1> Activity 4.1  | <h1> Advanced Data Analytics and Machine Learning </h1> |
# |--- | --- |
# **Name:** Jomarie Dupaya
# **Course and Section:** CPE019, CPE32S3 <br>
# **Instructor:** Engr. Roman Richard
# **Date Performed:** 2/21/24
# **Date Submitted:** 2/21/24
#
# <hr>

# %% [markdown]
# #Objective 1 Simple linear Regression
# #Part 1: Import the Libraries and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titanictestfile = '/content/titanic_test.csv'
titanictrainfile = '/content/titanic_train.csv'

# %% [markdown]
# # Part 2: Plot the Data

# %%
titanictestframe = pd.read_csv(titanictestfile)
titanictestframe.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %%
titanictrainframe = pd.read_csv(titanictrainfile)
titanictrainframe.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
titanictestframe.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
titanictrainframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
maletrainDf = titanictrainframe[(titanictrainframe.Sex == 'male')]
femaletrainDf = titanictrainframe[(titanictrainframe.Sex == 'female')]

# %%
malemean = maletrainDf[["Age","Pclass"]].mean(axis=1)
plt.scatter(malemean, maletrainDf["Survived"])
plt.show()
# %matplotlib inline

# %%
femalemean = femaletrainDf[["Age","Pclass"]].mean(axis=1)
plt.scatter(femalemean, femaletrainDf["Survived"])
plt.show()
# %matplotlib inline

# %% [markdown]
# # Part 3: Perform Simple Linear Regression on the SURVIVAL feature column

# %%
sns.regplot(x= "Survived", y = "Age", data = titanictrainframe)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# #Objective 2 Decision Tree
# #Part 1: Create a Decision Tree Classifier

# %% [markdown]
# **Step 1: Create the dataframe**
#
# **a) Import pandas and the csv file**

# %%
#Code cell 1
import pandas as pd
training = pd.read_csv("/content/titanic_train.csv")

# %% [markdown]
# **b) Verify the import and take a look at the data**

# %%
#Code cell 2
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Are there missing values in the data set?**
#
# -Yes, there are missing values in the dataset.

# %%
#Code cell 3
#view the first few rows of the data
training.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %% [markdown]
# **Step 2: Prepare the Data for the Decision Tree Model.**
#
# **a) Replace string data with numeric labels**
#
# **b) Verify that the Gender variable has been changed.**

# %%
#Code cell 4 & 5
training["Sex"] = training["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
training.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name  Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                              Heikkinen, Miss. Laina    1  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                            Allen, Mr. William Henry    0  35.0      0
# 5                                    Moran, Mr. James    0   NaN      0
# 6                             McCarthy, Mr. Timothy J    0  54.0      0
# 7                      Palsson, Master. Gosta Leonard    0   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut    1   4.0      1
# 11                           Bonnell, Miss. Elizabeth    1  58.0      0
# 12                     Saundercock, Mr. William Henry    0  20.0      0
# 13                        Andersson, Mr. Anders Johan    0  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina    1  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %% [markdown]
# **c) Address Missing Values in the Dataset**
#
# **d) Verify that the values have been replaced.**

# %%
#Code cell 6 & 7
training["Age"].fillna(training["Age"].mean(), inplace=True)
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %% [markdown]
# **What is the value that was used to replace the missing ages?**

# %%
#the replaced values in the missing ages are from the mean ages of the data
training.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name  Sex        Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.000000      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                              Heikkinen, Miss. Laina    1  26.000000      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                            Allen, Mr. William Henry    0  35.000000      0
# 5                                    Moran, Mr. James    0  29.699118      0
# 6                             McCarthy, Mr. Timothy J    0  54.000000      0
# 7                      Palsson, Master. Gosta Leonard    0   2.000000      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.000000      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# 10                    Sandstrom, Miss. Marguerite Rut    1   4.000000      1
# 11                           Bonnell, Miss. Elizabeth    1  58.000000      0
# 12                     Saundercock, Mr. William Henry    0  20.000000      0
# 13                        Andersson, Mr. Anders Johan    0  39.000000      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina    1  14.000000      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %% [markdown]
# **Step 3: Train and Score the Decision Tree Model.**
#
# **a) Create an array object with the variable that will be the target for the model.**

# %%
#Code cell 8
y_target = training["Survived"].values

# %% [markdown]
# **b) Create an array of the values that will be the input for the model.**

# %%
#Code cell 9
columns = ["Fare", "Pclass", "Sex", "Age", "SibSp"]
X_input = training[list(columns)].values

# %% [markdown]
# **c) Create the learned model.**

# %%
#Code cell 10
from sklearn import tree
#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
#train the model using the fit() method of the decision tree object.
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %% [markdown]
# **d) Evaluate the model**

# %%
#Code cell 11
clf_train.score(X_input,y_target)
# Out:
# 0.8226711560044894

# %% [markdown]
# **Step 6: Visualize the Tree**
#
# **a) Create the intermediate file output**

# %%
#Code cell 12
from six  import StringIO
with open("/content/titanic_train.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)

# %% [markdown]
# **b) Install Graphviz**

# %%
import graphviz

# %% [markdown]
# **c) Convert the intermediate file to a graphic**

# %%
#Code cell 13
# !dot -Tpng /content/titanic_train.dot -o /content/titanic.png

# %% [markdown]
# **d) Display the image**

# %%
#Code cell 14
from IPython.display import Image
#display the decison tree graphic
Image("/content/titanic.png")

# %% [markdown]
# **e) Interpret the tree**
#
# **What describes the group that had the most deaths by number? Which group had the most survivors?**
#
# -Based on the hierarchy the male had the most deaths.

# %% [markdown]
# #Part 2: Apply the Decision Tree Model
# **Step 1: Import and Prepare the Data**
#
# **a) Import the data.**

# %%
#Code cell 15
testing = pd.read_csv("/content/titanic_test.csv")
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# **How many records are in the data set?**
#
# -Based from the info() command there are 418 records in this data set
#
# **Which important variables(s) are missing values and how many are missing?**
# -The important variables that have missing values are Age, cabin, and fare with having missing values of 86 for Age, 326 for cabin and 1 for fare.

# %% [markdown]
# **b) Use a lambda expression to replace the "male" and "female" values with 0 for male and 1 for
# female..**

# %%
#code cell 16
testing["Sex"] = testing["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
testing.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# 11          903       1                         Jones, Mr. Charles Cresson
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13          905       2                               Howard, Mr. Benjamin
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
#
#     Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 0     0  34.5      0      0       330911   7.8292   NaN        Q
# 1     1  47.0      1      0       363272   7.0000   NaN        S
# 2     0  62.0      0      0       240276   9.6875   NaN        Q
# 3     0  27.0      0      0       315154   8.6625   NaN        S
# 4     1  22.0      1      1      3101298  12.2875   NaN        S
# 5     0  14.0      0      0         7538   9.2250   NaN        S
# 6     1  30.0      0      0       330972   7.6292   NaN        Q
# 7     0  26.0      1      1       248738  29.0000   NaN        S
# 8     1  18.0      0      0         2657   7.2292   NaN        C
# 9     0  21.0      2      0    A/4 48871  24.1500   NaN        S
# 10    0   NaN      0      0       349220   7.8958   NaN        S
# 11    0  46.0      0      0          694  26.0000   NaN        S
# 12    1  23.0      1      0        21228  82.2667   B45        S
# 13    0  63.0      1      0        24065  26.0000   NaN        S
# 14    1  47.0      1      0  W.E.P. 5734  61.1750   E31        S

# %% [markdown]
# **c) Replace the missing age values with the mean of the ages.**

# %%
#code cell 17
testing["Age"].fillna(testing["Age"].mean(), inplace=True)
testing["Fare"].fillna(testing["Fare"].mean(), inplace=True)

# %% [markdown]
# d) Verify that the values have been replaced.

# %%
#code cell 18
testing.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# 11          903       1                         Jones, Mr. Charles Cresson
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13          905       2                               Howard, Mr. Benjamin
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
#
#     Sex       Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 0     0  34.50000      0      0       330911   7.8292   NaN        Q
# 1     1  47.00000      1      0       363272   7.0000   NaN        S
# 2     0  62.00000      0      0       240276   9.6875   NaN        Q
# 3     0  27.00000      0      0       315154   8.6625   NaN        S
# 4     1  22.00000      1      1      3101298  12.2875   NaN        S
# 5     0  14.00000      0      0         7538   9.2250   NaN        S
# 6     1  30.00000      0      0       330972   7.6292   NaN        Q
# 7     0  26.00000      1      1       248738  29.0000   NaN        S
# 8     1  18.00000      0      0         2657   7.2292   NaN        C
# 9     0  21.00000      2      0    A/4 48871  24.1500   NaN        S
# 10    0  30.27259      0      0       349220   7.8958   NaN        S
# 11    0  46.00000      0      0          694  26.0000   NaN        S
# 12    1  23.00000      1      0        21228  82.2667   B45        S
# 13    0  63.00000      1      0        24065  26.0000   NaN        S
# 14    1  47.00000      1      0  W.E.P. 5734  61.1750   E31        S

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %% [markdown]
# **Step 2: Label the testing dataset**
#
# **a) Create the array of input variables from the testing data set.**

# %%
columns = ["Fare","Pclass", "Sex", "Age", "SibSp"]
X_input = testing[list(columns)].values
X_input
# Out:
# array([[ 7.8292    ,  3.        ,  0.        , 34.5       ,  0.        ],
#        [ 7.        ,  3.        ,  1.        , 47.        ,  1.        ],
#        [ 9.6875    ,  2.        ,  0.        , 62.        ,  0.        ],
#        ...,
#        [ 7.25      ,  3.        ,  0.        , 38.5       ,  0.        ],
#        [ 8.05      ,  3.        ,  0.        , 30.27259036,  0.        ],
#        [22.3583    ,  3.        ,  0.        , 30.27259036,  1.        ]])

# %% [markdown]
# **b) Apply the model to the testing data set.**

# %%
#code cell 20

target_labels = clf_train.predict(X_input)

target_labels = pd.DataFrame({'Est_Survival':target_labels, 'Name':testing['Name']})
#display the first few rows of the data set

target_labels.head(25)
# Out:
#     Est_Survival                                               Name
# 0              0                                   Kelly, Mr. James
# 1              1                   Wilkes, Mrs. James (Ellen Needs)
# 2              0                          Myles, Mr. Thomas Francis
# 3              0                                   Wirz, Mr. Albert
# 4              1       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5              0                         Svensson, Mr. Johan Cervin
# 6              1                               Connolly, Miss. Kate
# 7              0                       Caldwell, Mr. Albert Francis
# 8              1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9              0                            Davies, Mr. John Samuel
# 10             0                                   Ilieff, Mr. Ylio
# 11             0                         Jones, Mr. Charles Cresson
# 12             1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13             0                               Howard, Mr. Benjamin
# 14             1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15             1      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16             0                                  Keane, Mr. Daniel
# 17             0                                  Assaf, Mr. Gerios
# 18             1                       Ilmakangas, Miss. Ida Livija
# 19             1              Assaf Khalil, Mrs. Mariana (Miriam")"
# 20             0                             Rothschild, Mr. Martin
# 21             1                          Olsen, Master. Artur Karl
# 22             1               Flegenheim, Mrs. Alfred (Antoinette)
# 23             0                    Williams, Mr. Richard Norris II
# 24             1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)

# %% [markdown]
# **c) Evaluate the accuracy of the estimated labels**

# %%
#code cell 21
#import the numpy library as np
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("/content/titanic_all.csv")
# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])
# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) /float(len(testing_results))
percentage = "{:.0%}".format(acc)
percentage
# Out:
# '77%'

# %% [markdown]
# #Part 3: Evaluate the Decision Tree Model
#
# **Step 1: Import the data**

# %%
#code cell 22
all_data = pd.read_csv("/content/titanic_all.csv", usecols=['Survived','Pclass','Gender','Age','SibSp','Fare'])
#View info for the new dataframe
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   int64
#  1   Pclass    1308 non-null   int64
#  2   Gender    1308 non-null   object
#  3   Age       1045 non-null   float64
#  4   SibSp     1308 non-null   int64
#  5   Fare      1308 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 61.4+ KB

# %%
all_data.head()
# Out:
#    Survived  Pclass  Gender      Age  SibSp      Fare
# 0         1       1  female  29.0000      0  211.3375
# 1         1       1    male   0.9167      1  151.5500
# 2         0       1  female   2.0000      1  151.5500
# 3         0       1    male  30.0000      1  151.5500
# 4         0       1  female  25.0000      1  151.5500

# %% [markdown]
# **How many records are in the data set?**
#
# -There are 1308 records in the data set of titanic_all
#
# **Which important variables(s) are missing values and how many are missing?**
#
# -The important variable that is missing in values is the Age column which only has 1045 and and its missing 263 values.

# %% [markdown]
# **Step 2: Prepare the data.**
#
# **a) Remove the "male" and "female" strings and replace them with 0 and 1 respectively.**

# %%
#code cell 23
all_data["Gender"] = all_data["Gender"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)
all_data.head(15)
# Out:
#     Survived  Pclass  Gender      Age  SibSp      Fare
# 0          1       1       1  29.0000      0  211.3375
# 1          1       1       0   0.9167      1  151.5500
# 2          0       1       1   2.0000      1  151.5500
# 3          0       1       0  30.0000      1  151.5500
# 4          0       1       1  25.0000      1  151.5500
# 5          1       1       0  48.0000      0   26.5500
# 6          1       1       1  63.0000      1   77.9583
# 7          0       1       0  39.0000      0    0.0000
# 8          1       1       1  53.0000      2   51.4792
# 9          0       1       0  71.0000      0   49.5042
# 10         0       1       0  47.0000      1  227.5250
# 11         1       1       1  18.0000      1  227.5250
# 12         1       1       1  24.0000      0   69.3000
# 13         1       1       1  26.0000      0   78.8500
# 14         1       1       0  80.0000      0   30.0000

# %%
#code cell 24
all_data["Age"].fillna(all_data["Age"].mean(), inplace=True)
all_data.head(15)
# Out:
#     Survived  Pclass  Gender      Age  SibSp      Fare
# 0          1       1       1  29.0000      0  211.3375
# 1          1       1       0   0.9167      1  151.5500
# 2          0       1       1   2.0000      1  151.5500
# 3          0       1       0  30.0000      1  151.5500
# 4          0       1       1  25.0000      1  151.5500
# 5          1       1       0  48.0000      0   26.5500
# 6          1       1       1  63.0000      1   77.9583
# 7          0       1       0  39.0000      0    0.0000
# 8          1       1       1  53.0000      2   51.4792
# 9          0       1       0  71.0000      0   49.5042
# 10         0       1       0  47.0000      1  227.5250
# 11         1       1       1  18.0000      1  227.5250
# 12         1       1       1  24.0000      0   69.3000
# 13         1       1       1  26.0000      0   78.8500
# 14         1       1       0  80.0000      0   30.0000

# %%
all_data.info(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   int64
#  1   Pclass    1308 non-null   int64
#  2   Gender    1308 non-null   int64
#  3   Age       1308 non-null   float64
#  4   SibSp     1308 non-null   int64
#  5   Fare      1308 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 61.4 KB

# %% [markdown]
# **Step 2: Create the input and output variables for the training and testing data.**
#
# **a) Designate the input variables and output variables and generate the arrays.**

# %%
#code cell 25
#Import train_test_split() from the sklearn.model_selection libary
from sklearn.model_selection import train_test_split
#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
columns = ["Pclass", "Gender", "Age", "SibSp", "Fare"]
X = all_data[list(columns)].values
y = all_data["Survived"].values
#generate the four testing and training data arrays with the train_test_split () method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %% [markdown]
# **b) Train the model and fit it to the testing data.**

# %%
#code cell 26
#create the training decision tree object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)
#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %% [markdown]
# **c) Compare models by scoring each.**

# %%
#code cell 27
#score the model on the two datasets and store the scores in variables. Convert the scores to strings using str()
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))
#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8201530612244898 Testing score = 0.8053435114503816
